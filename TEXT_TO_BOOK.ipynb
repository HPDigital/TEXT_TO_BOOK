# %%
import os
import numpy as np
import faiss
import openai
from dotenv import load_dotenv
from langchain_openai.embeddings import OpenAIEmbeddings
from langchain.text_splitter import CharacterTextSplitter

# Cargar las variables de entorno desde el archivo .env
load_dotenv()

# Obtener la API Key desde las variables de entorno
openai_api_key = os.getenv("OPENAI_API_KEY")
if not openai_api_key:
    raise ValueError("No se encontró la API Key de OpenAI. Asegúrate de que el archivo .env está configurado correctamente.")

# Inicializar la API de OpenAI
openai.api_key = openai_api_key

# Funciones auxiliares
def leer_libros(directorio):
    libros = {}
    for archivo in os.listdir(directorio):
        if archivo.endswith(".txt"):
            ruta = os.path.join(directorio, archivo)
            try:
                with open(ruta, 'r', encoding='utf-8') as file:
                    libros[archivo] = file.read()
            except Exception as e:
                print(f"Error al leer el archivo {archivo}: {e}")
    return libros

def procesar_libros(libros):
    splitter = CharacterTextSplitter(chunk_size=2000)
    procesados = {}
    for nombre, texto in libros.items():
        procesados[nombre] = splitter.split_text(texto)
    return procesados

def vectorizar_libros(libros, modelo):
    embeddings, metadata = [], []
    for nombre, fragmentos in libros.items():
        for fragmento in fragmentos:
            try:
                emb = modelo.embed_documents([fragmento])[0]
                embeddings.append(emb)
                metadata.append({'libro': nombre, 'fragmento': fragmento})
            except Exception as e:
                print(f"Error al vectorizar fragmento de {nombre}: {e}")
    return np.array(embeddings), metadata

def crear_indice_faiss(embeddings):
    dim = embeddings.shape[1]
    index = faiss.IndexFlatL2(dim)
    index.add(embeddings)
    return index

def buscar_en_faiss(query, index, modelo, metadata, k=5):
    query_embedding = modelo.embed_query(query)
    distances, indices = index.search(np.array([query_embedding]), k)
    resultados = [(metadata[i], distances[0][j]) for j, i in enumerate(indices[0])]
    return resultados

# Nueva función para combinar las respuestas en un texto fluido
def combinar_resultados_en_un_texto(resultados):
    texto_combinado = "A continuación se presenta una recopilación de fragmentos relacionados con tu consulta:\n\n"
    for i, (resultado, distancia) in enumerate(resultados):
        if i == 0:
            texto_combinado += f"Comenzando con un extracto del libro *{resultado['libro']}*, encontramos:\n"
        else:
            texto_combinado += f"\nSiguiendo en el libro *{resultado['libro']}*, se observa lo siguiente:\n"
        texto_combinado += f"{resultado['fragmento'][:500]}...\n"  # Limitar a los primeros 500 caracteres

    texto_combinado += "\nEn resumen, los fragmentos anteriores proporcionan una perspectiva completa sobre el tema investigado."
    return texto_combinado

# Nueva función para generar un texto académico usando OpenAI API con la nueva interfaz 1.0.0+
def generar_texto_academico_con_openai(query, texto_completo):
    # Crear el prompt usando el texto completo
    prompt = (f"Usando el siguiente texto completo y tu propia base de datos, "
              f"elabora un texto académico completo y detallado explicando qué es '{query}', "
              f"en qué consiste el concepto de '{query}', "
              f"y proporciona un ejemplo de '{query}':\n\n")
    
    # Añadir el texto completo al prompt (limitado a 2500 caracteres si es necesario)
    prompt += f"{texto_completo[:3000]}\n\n"  # Ajusta el límite de caracteres si es necesario

    try:
        # Usar el método correcto con la nueva API de OpenAI
        response = openai.chat.completions.create(
            model="gpt-4",  # Cambia a "gpt-3.5-turbo" si no tienes acceso a GPT-4
            messages=[
                {"role": "system", "content": "Eres un experto en la creación de textos académicos. Proporciona respuestas detalladas, claras, y cubre el tema a profundidad. Usa una combinación de los textos adjuntos y tu base de datos."},
                {"role": "user", "content": prompt}
            ],
            max_tokens=6000,
            temperature=0.7
        )
        # Acceder a la respuesta correctamente
        return response.choices[0].message.content
    except Exception as e:
        return f"Error al generar el texto académico: {e}"



# Procesamiento principal
def main(directorio_libros):
    libros = leer_libros(directorio_libros)
    libros_procesados = procesar_libros(libros)
    modelo_embeddings = OpenAIEmbeddings(openai_api_key=openai_api_key)
    
    embeddings, metadata = vectorizar_libros(libros_procesados, modelo_embeddings)
    index = crear_indice_faiss(embeddings)
    
    # Realizar la búsqueda
    query = "Jobs to be done"
    resultados = buscar_en_faiss(query, index, modelo_embeddings, metadata)
    
    # Combinar los resultados en un solo texto fluido
    texto_final = combinar_resultados_en_un_texto(resultados)
    #print("Texto combinado:\n", texto_final)
    
    # Generar un texto académico usando OpenAI API
    texto_academico = generar_texto_academico_con_openai(query, texto_final)
    print("\nTexto académico generado por OpenAI:\n", texto_academico)

if __name__ == "__main__":
    main(r"C:\Users\HP\Desktop\CATO-CURSOS-2-2024\GER-TI CATO-2-2024\Cursos\SEMANA 8\TEXTOS")
# Out:
# Texto combinado:
#  A continuación se presenta una recopilación de fragmentos relacionados con tu consulta:
#
# Comenzando con un extracto del libro *StrategyzerWebinarValuePropositionCanvasBestPractices.txt*, encontramos:
# broadcast is now starting all attendees are in listen-only mode hi everybody welcome to another stretch at webinar session the you topic today is the value proposition canvas best practices we're just about two minutes away from starting so in the meantime why don't you think about what you'd hope to learn from today's session and you can share it in the questions box or the chat box in the GoToWebinar control panel or you can tweet it to us at strategize err and if you use the hashtag strategy ...
#
# Siguiendo en el libro *200526Sesion7DiseñandolaPropuestadeValor.txt*, se observa lo siguiente:
# [Música] este es mi one player se acuerdan de mi mapa hay que hacerlo grande para que puedan ver todos paisa en el one page air es el mapa para mí es el mapa del texto sobre todo lo que hacemos en una página qué son esos 12 pasos hemos dedicado nuestras sesiones anteriores al primer cuadrito que es el canvas de la propuesta de valor de hecho hoy nos vamos a regresar a ese canvas de la propuesta de valor y entonces nos nos moveremos al canvas del modelo de negocio de ahí nos moveremos al modelo d...
#
# Siguiendo en el libro *video1_Diseñando_la_Propuesta_de_Valor.txt*, se observa lo siguiente:
# [Música] este es mi one player se acuerdan de mi mapa hay que hacerlo grande para que puedan ver todos paisa en el one page air es el mapa para mí es el mapa del texto sobre todo lo que hacemos en una página qué son esos 12 pasos hemos dedicado nuestras sesiones anteriores al primer cuadrito que es el canvas de la propuesta de valor de hecho hoy nos vamos a regresar a ese canvas de la propuesta de valor y entonces nos nos moveremos al canvas del modelo de negocio de ahí nos moveremos al modelo d...
#
# Siguiendo en el libro *CómoplasmarlaPROPUESTAdeVALORdetunegocioExpertoentecnologíaIsaccGonzálezParte3🎙️📈.txt*, se observa lo siguiente:
# comercial la parte de las ventas la parte administrativa y la parte operacional entonces dije Okay pues lo que tengo que hacer es que tengo que hacer que número uno eso ya no dependa de mí Y número dos Cómo le hago para que dependa de otra gente y número tres Cómo le hago para que si esa gente no está no se me caiga sí Entonces es vas Armando procesos vas este diciendo tú tú yaas a hacer este de aquí y no más sí Y si haces eso bien todo lo a funcionar bien entonces vas Armando los distintos engr...
#
# Siguiendo en el libro *Texto_video_2.txt*, se observa lo siguiente:
# La transmisión ya está comenzando. Todos los asistentes están en modo de solo escucha. Hola a todos, bienvenidos a otra parte de la sesión del seminario web. El tema de hoy es las mejores prácticas del lienzo de propuesta de valor. Estamos a solo dos minutos de comenzar. Mientras tanto, ¿por qué no? piensas en lo que esperas aprender de la sesión de hoy y puedes compartirlo en el cuadro de preguntas o en el cuadro de chat en el panel de control de GoToWebinar o puedes twittearlo en strategize er...
#
# En resumen, los fragmentos anteriores proporcionan una perspectiva completa sobre el tema investigado.
#
# Texto académico generado por OpenAI:
#  'Jobs to be done' es un concepto que se refiere a la comprensión de las necesidades y deseos subyacentes de los clientes, que los llevan a "contratar" un producto o servicio para satisfacer esas necesidades o deseos. Este marco fue popularizado por Clayton Christensen en su libro "The Innovator's Solution" y es un pilar fundamental en el diseño de la propuesta de valor y el modelo de negocio.
#
# En esencia, 'Jobs to be done' propone que los clientes no compran productos o servicios, sino que los "contratan" para hacer un trabajo. Por "trabajo" se entiende una tarea o actividad que los clientes necesitan realizar y que tiene un resultado esperado. Un 'Job to be done' puede ser funcional (por ejemplo, cortar el césped), emocional (sentirse seguro) o social (ser aceptado por un grupo).
#
# Este concepto ayuda a las empresas a entender mejor a sus clientes, ya que se centra en sus problemas y necesidades en lugar de en las características de un producto o servicio. En lugar de preguntarse "¿Qué podemos hacer mejor en nuestro producto?", las empresas pueden preguntarse "¿Qué trabajo está intentando hacer nuestro cliente y cómo podemos ayudarlo a hacerlo mejor?".
#
# Este enfoque puede ser especialmente útil para la innovación, ya que permite a las empresas identificar oportunidades no satisfechas en el mercado y desarrollar soluciones que satisfacen mejor las necesidades de los clientes.
#
# Un ejemplo de 'Jobs to be done' podría ser el de una persona que compra un taladro. El 'Job to be done' no es comprar un taladro, sino hacer un agujero en la pared. Este enfoque permite a los fabricantes de taladros pensar en nuevas formas de satisfacer esta necesidad, más allá de simplemente hacer taladros más potentes o más baratos. Por ejemplo, podrían considerar servicios de alquiler de taladros, taladros más fáciles de usar, o incluso soluciones alternativas para colgar cuadros sin necesidad de hacer agujeros en la pared.
#
# El concepto de 'Jobs to be done' se utiliza en conjunto con herramientas como el lienzo de la propuesta de valor y el lienzo del modelo de negocio para diseñar y evaluar propuestas de valor que satisfagan de manera efectiva las necesidades de los clientes. El lienzo de la propuesta de valor, por ejemplo, ayuda a las empresas a entender cómo sus productos o servicios pueden satisfacer los 'Jobs to be done' de los clientes, mientras que el lienzo del modelo de negocio ayuda a las empresas a entender cómo pueden entregar y capturar valor a partir de estas propuestas de valor.
